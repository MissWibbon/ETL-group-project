# %%
import pandas as pd
import numpy as np
# Dependencies
from matplotlib import pyplot as plt
from scipy.stats import linregress
from sklearn import datasets

# %%
# Before choosing data, I have inspected multiple sources such as Wikipedia, Kaggle, and Yahoo Finance for picking
# the right source. I have downloaded csv file of S&P 500 index price from Yahoo Finance, and performed data cleaning
# using panads
df = pd.read_csv("Resources/S&P 500 Weekly.csv", header = 0)
df.head(2)
# Also, we have chose to use weekly price of the stocks as we are comparing the values to weekly values of 
# Coronavirus data.

#
# Out:
#          Date         Open         High          Low        Close  \
# 0  2015-05-18  2127.790039  2134.719971  2122.590088  2126.060059
# 1  2015-05-25  2125.340088  2126.219971  2099.179932  2107.389893
#
#      Adj Close       Volume
# 0  2126.060059   8668200000
# 1  2107.389893  13377830000

# %%
csv_file = "Resources/Weekly_Counts_of_Deaths_by_State_and_Select_Causes__2019-2020-new.csv"
csv_file2 = "Resources/Weekly_Counts_of_Deaths_by_State_and_Select_Causes__2014-2018.csv"

cdc_df = pd.read_csv(csv_file)
cdc_df2 = pd.read_csv(csv_file2)

cdc_df = cdc_df[['Jurisdiction of Occurrence', 'MMWR Year', 'MMWR Week', 'Week Ending Date', 'All Cause', 'Natural Cause', 'Septicemia (A40-A41)', 'Malignant neoplasms (C00-C97)', 'Diabetes mellitus (E10-E14)', 'Alzheimer disease (G30)', 'Influenza and pneumonia (J10-J18)', 'Chronic lower respiratory diseases (J40-J47)', 'Other diseases of respiratory system (J00-J06,J30-J39,J67,J70-J98)', 'Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)', 'Symptoms, signs and abnormal clinical and laboratory findings, not elsewhere classified (R00-R99)', 'Diseases of heart (I00-I09,I11,I13,I20-I51)', 'Cerebrovascular diseases (I60-I69)', 'COVID-19 (U071, Multiple Cause of Death)', 'COVID-19 (U071, Underlying Cause of Death)']]
cdc_df2 = cdc_df2[['Jurisdiction of Occurrence', 'MMWR Year', 'MMWR Week', 'Week Ending Date', 'All  Cause', 'Natural Cause', 'Septicemia (A40-A41)', 'Malignant neoplasms (C00-C97)', 'Diabetes mellitus (E10-E14)', 'Alzheimer disease (G30)', 'Influenza and pneumonia (J10-J18)', 'Chronic lower respiratory diseases (J40-J47)', 'Other diseases of respiratory system (J00-J06,J30-J39,J67,J70-J98)', 'Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)', 'Symptoms, signs and abnormal clinical and laboratory findings, not elsewhere classified (R00-R99)', 'Diseases of heart (I00-I09,I11,I13,I20-I51)', 'Cerebrovascular diseases (I60-I69)']]
cdc_df2
# Out:
#       Jurisdiction of Occurrence  MMWR Year  MMWR Week Week Ending Date  \
# 0                        Alabama       2014          1       01/04/2014
# 1                        Alabama       2014          2       01/11/2014
# 2                        Alabama       2014          3       01/18/2014
# 3                        Alabama       2014          4       01/25/2014
# 4                        Alabama       2014          5       02/01/2014
# ...                          ...        ...        ...              ...
# 13828                    Wyoming       2018         48       12/01/2018
# 13829                    Wyoming       2018         49       12/08/2018
# 13830                    Wyoming       2018         50       12/15/2018
# 13831                    Wyoming       2018         51       12/22/2018
# 13832                    Wyoming       2018         52       12/29/2018
#
#        All  Cause  Natural Cause  Septicemia (A40-A41)  \
# ...

# %%
# For the Columns, we have chose to use Date, Adj Close, and Volume.
# Thus, using usecols, we have only selecetd "Date","Adj Close","Volume" columns
df = pd.read_csv("Resources/S&P 500 Weekly.csv", usecols = ["Date","Adj Close","Volume"])
df
# Out:
#            Date    Adj Close       Volume
# 0    2015-05-18  2126.060059   8668200000
# 1    2015-05-25  2107.389893  13377830000
# 2    2015-06-01  2092.830078  15604780000
# 3    2015-06-08  2094.110107  15214050000
# 4    2015-06-15  2109.989990  17173880000
# ..          ...          ...          ...
# 257  2020-04-20  2836.739990  26476650000
# 258  2020-04-27  2830.709961  28763560000
# 259  2020-05-04  2929.800049  24736450000
# 260  2020-05-11  2863.699951  27177120000
# 261  2020-05-18  2971.610107  16326590000
#
# [262 rows x 3 columns]

# %%
cdc2014_df = cdc_df2.loc[cdc_df2['MMWR Year'] == 2014]
cdc2015_df = cdc_df2.loc[cdc_df2['MMWR Year'] == 2015]
cdc2016_df = cdc_df2.loc[cdc_df2['MMWR Year'] == 2016]
cdc2017_df = cdc_df2.loc[cdc_df2['MMWR Year'] == 2017]
cdc2018_df = cdc_df2.loc[cdc_df2['MMWR Year'] == 2018]
cdc2019_df = cdc_df.loc[cdc_df['MMWR Year'] == 2019]
cdc2020_df = cdc_df.loc[cdc_df['MMWR Year'] == 2020]

week1_2014disease = cdc2014_df.groupby('MMWR Week').sum()
week1_2015disease = cdc2015_df.groupby('MMWR Week').sum()
week1_2016disease = cdc2016_df.groupby('MMWR Week').sum()
week1_2017disease = cdc2017_df.groupby('MMWR Week').sum()
week1_2018disease = cdc2018_df.groupby('MMWR Week').sum()
week1_2019disease = cdc2019_df.groupby('MMWR Week').sum()
week1_2020disease = cdc2020_df.groupby('MMWR Week').sum()

year2015 = df[df['Date'].str.contains('2015')]
year2016 = df[df['Date'].str.contains('2016')]
year2017 = df[df['Date'].str.contains('2017')]
year2018 = df[df['Date'].str.contains('2018')]
year2019 = df[df['Date'].str.contains('2019')]
year2020 = df[df['Date'].str.contains('2020')]


year2015.reset_index(drop =True,inplace=True)
year2016.reset_index(drop =True,inplace=True)
year2017.reset_index(drop =True,inplace=True)
year2018.reset_index(drop =True,inplace=True)
year2019.reset_index(drop =True,inplace=True)
year2020.reset_index(drop =True,inplace=True)

# %%
year2020
#year2020['Adj Close']
# Out:
# 0     3265.350098
# 1     3329.620117
# 2     3295.469971
# 3     3225.520020
# 4     3327.709961
# 5     3380.159912
# 6     3337.750000
# 7     2954.219971
# 8     2972.370117
# 9     2711.020020
# 10    2304.919922
# 11    2541.469971
# 12    2488.649902
# 13    2789.820068
# 14    2874.560059
# 15    2836.739990
# 16    2830.709961
# 17    2929.800049
# 18    2863.699951
# 19    2971.610107
# Name: Adj Close, dtype: float64

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.set_ylabel('Deaths')
ax1.set_title('2015 S&P Volume')
plt.plot(year2015['Volume'], label="Volume")
ax1.legend();
plt.savefig('Resources/2015-s&p-volume.png')

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.set_ylabel('Deaths')
ax1.set_xlabel('Week')
ax1.set_title('2015 S&P Close')
plt.plot(year2015['Adj Close'], label="Adj Close")
ax1.legend();
plt.savefig('Resources/2015-s&p-close.png')

# %%
year2016.reset_index()

fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.set_ylabel('Deaths')
ax1.set_xlabel('Week')
ax1.set_title('2016 S&P Volume')
plt.plot(year2016['Volume'], label="Volume")
ax1.legend();
plt.savefig('Resources/2016-s&p-volume.png')

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.set_ylabel('Deaths')
ax1.set_xlabel('Week')
ax1.set_title('2016 S&P Close')
plt.plot(year2016['Adj Close'], label="Adj Close")
ax1.legend();
plt.savefig('Resources/2016-s&p-close.png')

# %%
year2017.reset_index()

fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.set_ylabel('Deaths')
ax1.set_xlabel('Week')
ax1.set_title('2017 S&P Volume')
plt.plot(year2017['Volume'], label="Volume")
ax1.legend();
plt.savefig('Resources/2017-s&p-volume.png')

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.set_ylabel('Deaths')
ax1.set_xlabel('Week')
ax1.set_title('2017 S&P Close')
plt.plot(year2017['Adj Close'], label="Adj Close")
ax1.legend();
plt.savefig('Resources/2017-s&p-close.png')

# %%
year2018.reset_index()

fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.set_ylabel('Deaths')
ax1.set_xlabel('Week')
ax1.set_title('2018 S&P Volume')
plt.plot(year2018['Volume'], label="Volume")
ax1.legend();
plt.savefig('Resources/2018-s&p-volume.png')

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.set_ylabel('Deaths')
ax1.set_xlabel('Week')
ax1.set_title('2018 S&P Close')
plt.plot(year2018['Adj Close'], label="Adj Close")
ax1.legend();
plt.savefig('Resources/2018-s&p-close.png')

# %%
year2019.reset_index()

fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.set_ylabel('Deaths')
ax1.set_xlabel('Week')
ax1.set_title('2019 S&P Volume')
plt.plot(year2019['Volume'], label="Volume")
ax1.legend();
plt.savefig('Resources/2019-s&p-volume.png')

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.set_ylabel('Deaths')
ax1.set_xlabel('Week')
ax1.set_title('2019 S&P Close')
plt.plot(year2019['Adj Close'], label="Adj Close")
ax1.legend();
plt.savefig('Resources/2019-s&p-close.png')

# %%
year2020.reset_index()

fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.set_ylabel('Deaths')
ax1.set_xlabel('Week')
ax1.set_title('2020 S&P Volume')
plt.plot(year2020['Volume'], label="Volume")
ax1.legend();
plt.savefig('Resources/2020-s&p-volume.png')

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.set_ylabel('Deaths')
ax1.set_xlabel('Week')
ax1.set_title('2020 S&P Close')
plt.plot(year2020['Adj Close'], label="Adj Close")
ax1.legend();
plt.savefig('Resources/2020-s&p-close.png')

# %%
cdc2020_df = cdc_df.loc[cdc_df['MMWR Year'] == 2020]

week1_2020disease = cdc2020_df.groupby('MMWR Week').sum()

fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.set_ylabel('Deaths')
ax1.set_title('2020 COVID-19 Deaths & Adj Close')
ax1.set_xlabel('Week')
plt.plot(week1_2020disease['Diseases of heart (I00-I09,I11,I13,I20-I51)'], label="Heart Disease Deaths")
plt.plot(week1_2020disease['Influenza and pneumonia (J10-J18)'], label="Influenze Pneumonia")
plt.plot(week1_2020disease['COVID-19 (U071, Underlying Cause of Death)'], label="COVID-19 Underlying Cause")

plt.plot(year2020['Adj Close'], label="Adj Close")
ax1.legend();
plt.savefig('Resources/2020-cdc-s&p.png')
